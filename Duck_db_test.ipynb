# %%
import duckdb
import pandas as pd
import matplotlib.pyplot as plt

# Connect to an in-memory database
con = duckdb.connect()

# --- Your setup code (which is correct) ---
con.execute("INSTALL httpfs;")
con.execute("LOAD httpfs;")
con.execute("""
SET s3_endpoint='122.176.133.73:9000';
SET s3_use_ssl=false;
SET s3_access_key_id='minioadmin';
SET s3_secret_access_key='minioadmin';
""")
con.execute("SET s3_url_style='path';") 
con.execute("PRAGMA threads=8;")
con.execute("PRAGMA enable_object_cache;")

# --- THE MISSING STEP: Querying a file from S3 ---
# Replace with your actual S3 bucket and file path
# This can be a .parquet, .csv, or .json file
s3_file_path = 's3://duckdata/ORATS/Options/**/*.parquet'

try:
    # Execute a query on the S3 file and fetch the result as a Pandas DataFrame
    print(f"Querying data from: {s3_file_path}")
    df = con.execute(f"""
        SELECT *
        FROM '{s3_file_path}'
        LIMIT 2;
    """).df()

    print("\n✅ Query successful! First 5 rows of data:")
    print(df.head())

except Exception as e:
    print(f"\n❌ An error occurred during the query: {e}")

# finally:
#     # It's good practice to close the connection
#     con.close()
# Out:
# Querying data from: s3://duckdata/ORATS/Options/**/*.parquet
#
# ✅ Query successful! First 5 rows of data:
#       expiry  strike  dte  optionType                  ts     low    high  \
# 0 2024-01-26   421.0   25          -1 2024-01-02 17:13:00  17.180  17.180
# 1 2024-01-12   414.0   11          -1 2024-01-02 17:13:00  10.415  10.415
#
#      open   close  volume  ...  askSize  bidPrice  askPrice     bidIv  \
# 0  17.180  17.180     0.0  ...     50.0     17.12     17.24  0.137857
# 1  10.415  10.415     0.0  ...    151.0     10.34     10.49  0.142671
#
#       askIv        iv    oi  stockPrice        day ticker
# 0  0.145115  0.141486  15.0       404.0 2024-01-02    QQQ
# 1  0.151996  0.147333  54.0       404.0 2024-01-02    QQQ
#
# [2 rows x 21 columns]

# %%
try:
    print("🔭 Finding all .parquet files using the official read_parquet method...")
    print("(This will be slow due to the massive size of the dataset)")

    # Define the recursive path
    s3_path = 's3://duckdata/ORATS/Options/**/*.parquet'

    # This query uses read_parquet with filename=true to get a list of all files.
    # It is the correct and documented way to handle recursive file discovery.
    all_files_df = con.execute(f"""
        SELECT DISTINCT filename
        FROM read_parquet('{s3_path}', filename=true);
    """).df()

    total_files = len(all_files_df)

    print(f"\n✅ Query complete! Found a total of {total_files:,} files.")
    print("\nHere are the first 10 files found:")

    # The column name from this function is 'filename'
    for f in all_files_df['filename'].head(10).tolist():
        print(f)

except Exception as e:
    print(f"\n❌ An error occurred: {e}")

# %%
# --- 2. Define the ticker and date you want ---
target_ticker = 'SPY'
target_day = '2024-07-29'
target_expiry = '2024-08-16'

try:
    print(f"🚀 Running optimized query for {target_ticker} on {target_day}...")

    # This query uses hive_partitioning=true to leverage the folder structure
    data_df = con.execute(f"""
        SELECT *
        FROM read_parquet(
            's3://duckdata/ORATS/Options/**/*.parquet',
            hive_partitioning=true
        )
        WHERE ticker = '{target_ticker}'
          AND day = DATE '{target_day}'
          AND expiry = DATE '{target_expiry}';
    """).df()

    print(f"\n✅ Query successful! Found {len(data_df)} rows of data.")
    print(data_df.head())

except Exception as e:
    print(f"\n❌ An error occurred: {e}")

# %%
import duckdb



# --- 2. Define the ticker and date you want ---
target_ticker = 'QQQ'
target_day = '2024-07-29'

# --- 3. Build a DIRECT path without the recursive '**' glob ---
s3_path = f"s3://duckdata/ORATS/Options/ticker={target_ticker}/day={target_day}/*.parquet"

try:
    print(f"🚀 Running hyper-optimized query with direct path:\n{s3_path}")

    # This query is now as fast as possible because there's no discovery phase.
    data_df = con.execute(f"""
        SELECT
            ts, strike, expiry, bidPrice, stockPrice
        FROM read_parquet('{s3_path}')
        ; -- Limiting rows for a quick test
    """).df()

    print(f"\n✅ Query successful! Found {len(data_df)} rows of data.")
    print(data_df.head())

except Exception as e:
    print(f"\n❌ An error occurred: {e}")

# %%
# --- 2. Define the ticker and date ---
target_ticker = 'SPY'
target_day = '2025-01-02'

# --- 3. Build the direct path for the query ---
s3_path = f"s3://duckdata/ORATS/Options/ticker={target_ticker}/day={target_day}/*.parquet"

try:
    print("🚀 Running query to find near-the-money options...")

    data_df = con.execute(f"""
        SELECT
            ts, strike, expiry, bidPrice, stockPrice
        FROM read_parquet('{s3_path}')
        WHERE
            -- This is the new filter for the strike price
            strike > stockPrice * 0.92 AND strike < stockPrice * 1.04;

    """).df()

    print(f"\n✅ Query successful! Filtered down to {len(data_df)} rows.")
    print(data_df.head())

except Exception as e:
    print(f"\n❌ An error occurred: {e}")

# %%
data_df['ts_eastern'] = data_df['ts'].dt.tz_localize('UTC').dt.tz_convert('America/New_York')

# %%
data_df['ts'].unique()

# %%
# --- The One-Liner ---
data_df['ts_eastern'] = pd.to_datetime(data_df['ts']).dt.tz_localize('UTC').dt.tz_convert('America/New_York')

# %%
data_df.sort_index()

# %%
atm = data_df[(data_df['strike'] > data_df["stockPrice"]*0.999) & (data_df['strike'] < data_df["stockPrice"]*1.001)]

# %%
spy_df

# %%
spy_df = pd.read_parquet(r"C:\Data\Aggregate_Data\Us_etfs\SPY_15min_2019_2025.parquet")
rdf = pd.read_csv(r"C:\Repos\US_strategies\exposure_series.csv")
rdf['Unnamed: 0'] = pd.to_datetime(rdf["Unnamed: 0"])
rdf.set_index('Unnamed: 0' , inplace=True)
rdf = rdf[rdf.index.year>=2024]
rdf = rdf.between_time('9:30', '15:45')

import numpy as np
# Handle potential NaN values by treating them as 0 for comparison
rdf['net_exposure_filled'] = rdf['net_exposure'].fillna(0)

# 2. Get the exposure from the previous row
rdf['prev_exposure'] = rdf['net_exposure_filled'].shift(1).fillna(0)

# 3. Apply your conditional logic using np.select
conditions = [
    rdf['net_exposure_filled'] > rdf['prev_exposure']+10000,  # Any increase
    rdf['net_exposure_filled'] < rdf['prev_exposure'] - 10000   # Any decrease
]

# Define the outcomes for each condition
outcomes = [1, -1]

# The default value if neither condition is met (i.e., they are equal) is 0
rdf['change_posn'] = np.select(conditions, outcomes, default=0)

rdf['change_in_exposure'] = rdf['net_exposure_filled'] - rdf['prev_exposure']
rdf = rdf.join(spy_df)

# %%
rdf
# Out:
#                      net_exposure  net_exposure_filled  prev_exposure  \
# Unnamed: 0
# 2024-01-02 09:30:00      0.000000             0.000000       0.000000
# 2024-01-02 09:45:00      0.000000             0.000000       0.000000
# 2024-01-02 10:00:00      0.000000             0.000000       0.000000
# 2024-01-02 10:15:00      0.000000             0.000000       0.000000
# 2024-01-02 10:30:00      0.000000             0.000000       0.000000
# ...                           ...                  ...            ...
# 2024-09-06 14:45:00  95974.198063         95974.198063   95821.864262
# 2024-09-06 15:00:00  96431.218838         96431.218838   95974.198063
# 2024-09-06 15:15:00  96278.875351         96278.875351   96431.218838
# 2024-09-06 15:30:00  96024.979225         96024.979225   96278.875351
# 2024-09-06 15:45:00  95923.416901         95923.416901   96024.979225
#
#                      change_posn  change_in_exposure  SPY_open  SPY_close  \
# Unnamed: 0
# 2024-01-02 09:30:00            0            0.000000    472.16     471.81
# 2024-01-02 09:45:00            0            0.000000    471.80     472.27
# 2024-01-02 10:00:00            0            0.000000    472.28     472.12
# 2024-01-02 10:15:00            0            0.000000    472.12     471.76
# 2024-01-02 10:30:00            0            0.000000    471.77     471.86
# ...                          ...                 ...       ...        ...
# 2024-09-06 14:45:00            0          152.333801    540.31     540.45
# 2024-09-06 15:00:00            0          457.020775    540.45     541.10
# 2024-09-06 15:15:00            0         -152.343487    541.11     541.33
# 2024-09-06 15:30:00            0         -253.896126    541.33     540.34
# 2024-09-06 15:45:00            0         -101.562325    540.33     540.42
#
#                      SPY_high  SPY_low  SPY_volume
# Unnamed: 0
# 2024-01-02 09:30:00    472.80   471.71   5562913.0
# 2024-01-02 09:45:00    472.28   471.36   4317417.0
# 2024-01-02 10:00:00    472.71   471.98   2581394.0
# 2024-01-02 10:15:00    472.42   471.59   2472668.0
# 2024-01-02 10:30:00    471.96   471.30   2342245.0
# ...                       ...      ...         ...
# 2024-09-06 14:45:00    540.65   539.71    684297.0
# 2024-09-06 15:00:00    541.43   540.40    962149.0
# 2024-09-06 15:15:00    541.88   540.86   1261053.0
# 2024-09-06 15:30:00    541.39   540.20   2678018.0
# 2024-09-06 15:45:00    541.70   539.67   7931004.0
#
# [4472 rows x 10 columns]

# %%
rdf.to_csv(r"test.csv")

# %%
import pandas as pd
import numpy as np
import pandas_market_calendars as mcal

# --- (Your setup code) ---

open_positions = []
trade_log = []
option_multiplier = 100
hedge_ratio = 0.50

# --- 1. Get the NYSE market calendar ---
nyse = mcal.get_calendar('NYSE')
print("🚀 Starting backtest with dynamic quantity...")

# Loop through each row of your exposure data
for timestamp, row in rdf.iterrows():
    marker = row['change_posn']
    current_exposure = row['net_exposure']
    change_in_exposure = row['change_in_exposure']
    
    
    positions_to_keep = []
    if open_positions:
        for position in open_positions:
            expiry_date = pd.to_datetime(position['expiry']).date()
            if timestamp.date() >= expiry_date:
                print(f"   Expiring position with strike {position['strike']} on {timestamp.date()}")
                exit_price = 0.01 # Simulate fetching a closing price
                
                try:
                    # --- DYNAMICALLY FETCH CLOSING PRICE ---
                    # 1. Define the START of the closing window (15:58) and convert to UTC
                    close_window_start_ny = pd.to_datetime(f"{expiry_date} 15:57:00").tz_localize('America/New_York')
                    close_window_end_ny = pd.to_datetime(f"{expiry_date} 15:59:00").tz_localize('America/New_York')
                    close_window_start_utc_str = close_window_start_ny.tz_convert('UTC').strftime('%Y-%m-%d %H:%M:%S')
                    close_window_end_utc_str = close_window_end_ny.tz_convert('UTC').strftime('%Y-%m-%d %H:%M:%S')
                    closing_price_query = f"""
                    SELECT *
                    FROM read_parquet('s3://duckdata/ORATS/Options/ticker=SPY/day={expiry_date.strftime('%Y-%m-%d')}/*.parquet')
                    WHERE 
                        ts >= '{close_window_start_utc_str}'  AND
                        ts <= '{close_window_end_utc_str}'AND
                        optionType = 1 AND
                        strike = {position['strike']}  AND
                        expiry = '{position['expiry']}'  ; """      

                    price_data = con.execute(closing_price_query).df()
                    #print(f"Price data is {price_data}")
                    if not price_data.empty:
                        # 3. Calculate the AVERAGE of the bid prices found
                        exit_price = price_data['askPrice'].mean()
                        print(f"   Found {len(price_data)} prices in closing window. Avg exit price: ${exit_price:.2f}")
                        
                    else:
                        print(f"   No closing price found for strike {position['strike']} on {expiry_date}. Assuming $0.05.")

                except Exception as e:
                    print(f"   Error fetching closing price for strike {position['strike']}: {e}. Assuming $0.00.")

                
                pnl = (position['entry_price'] - exit_price) * position['quantity'] * option_multiplier
                print(f"Pnl of hedge was {pnl}")
                position.update({'exit_ts': timestamp, 'exit_price': exit_price, 'pnl': pnl, 'exit_reason': 'Expired'})
                trade_log.append(position)
            else:
                positions_to_keep.append(position)
        open_positions = positions_to_keep

    # --- 2. HANDLE SIGNALS (SCALE OUT or SCALE IN) ---
    if marker == -1:
        if not open_positions:
            print(f"  ⚠️ {timestamp.date()}: Received SCALE_OUT signal, but no open positions.")
            continue


    # --- ENTRY LOGIC with Quantity Calculation ---
    if marker == 1 :
        print(f"Processing timestamp  {timestamp}")     
        # (Your code for calculating dates)
        schedule = nyse.schedule(start_date=timestamp.date(), end_date=timestamp.date() + pd.Timedelta(days=5))
        next_trading_day = schedule.index[1].date()
        entry_date_str = timestamp.strftime('%Y-%m-%d')
        expiry_date_str = next_trading_day.strftime('%Y-%m-%d')
        #print(f"Got entry date as {entry_date_str} and exit as {expiry_date_str}")

        # The 'try' block starts here
        try:


            utc_timestamp_for_query = timestamp.tz_localize('America/New_York').tz_convert('UTC')
            utc_timestamp_str = utc_timestamp_for_query.strftime('%Y-%m-%d %H:%M:%S')
            #print(f"Searching UTC timestamp as {utc_timestamp_str}")
            
            options_data = con.execute(f"""
                SELECT *
                FROM read_parquet('s3://duckdata/ORATS/Options/ticker=SPY/day={timestamp.strftime('%Y-%m-%d')}/*.parquet')
                WHERE 
                    ts = '{utc_timestamp_str}'  AND
                    optionType = 1 AND
                    expiry BETWEEN '{timestamp.strftime('%Y-%m-%d')}' AND '{expiry_date_str}' AND
                    strike>stockPrice*1.002 AND
                    bidPrice<1.5 AND bidPrice>0.9
                ORDER BY abs(strike - stockPrice) DESC
                LIMIT 5;
            """).df()       

            if len(options_data) > 0:
                print(f"Found data of options as {options_data}")
                target_option = options_data.iloc[0] # Select ATM+2 strike

                asset_price_at_entry = target_option['stockPrice']
                option_multiplier = 100
                delta_of_option = 0.3
                delta_per_contract = delta_of_option * option_multiplier
                

                print(f"Exposure is : {current_exposure}")
                notional_to_hedge = current_exposure * 0.5
                notional_per_contract = asset_price_at_entry * option_multiplier
                                # This is the number of shares your portfolio is equivalent to
                shares_to_hedge = notional_to_hedge / asset_price_at_entry
                qty_to_sell = 0 
                if delta_per_contract > 0:
                    qty_to_sell = int(round(shares_to_hedge / delta_per_contract))
                    print(f"Qty to sell is {qty_to_sell}")
                
                
                if qty_to_sell > 0:
                    new_position = {
                        'entry_ts': timestamp, 'strike': target_option['strike'], 'expiry': expiry_date_str,
                        'entry_price': target_option['bidPrice'], 'quantity': qty_to_sell, 'initial_delta': delta_of_option
                    }
                    open_positions.append(new_position)
                    print(f"  ✅ {timestamp.date()}: SCALED IN by selling {qty_to_sell} contracts of strike {new_position['strike']}")
            else:
                print(f"  ⚠️ {timestamp.date()}: No options data found for this entry signal.")
        except Exception as e:
            print(f"  ❌ Error processing {timestamp}: {e}")

# --- 3. Close any remaining positions at the end of the backtest ---
for pos in open_positions:
    pos['exit_reason'] = 'End of Backtest'
    trade_log.append(pos)

print("\n✅ Backtest finished.")
# Out:
# 🚀 Starting backtest with dynamic quantity...
# Processing timestamp  2024-01-04 11:30:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-01-05   472.0    2           1 2024-01-04 16:30:00  1.065  1.065
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.065  1.065   565.0  ...    192.0      1.06      1.07  0.146475  0.147454
#
#          iv       oi  stockPrice        day ticker
# 0  0.146965  13025.0      470.74 2024-01-04    SPY
#
# [1 rows x 21 columns]
# Exposure is : 99947.34
# Qty to sell is 4
#   ✅ 2024-01-04: SCALED IN by selling 4 contracts of strike 472.0
#    Expiring position with strike 472.0 on 2024-01-05
#    Found 3 prices in closing window. Avg exit price: $0.01
# Pnl of hedge was 420.0
# Processing timestamp  2024-01-05 10:15:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-01-08   471.0    4           1 2024-01-05 15:15:00  1.065  1.065
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.065  1.065  2143.0  ...    284.0      1.06      1.07  0.090849  0.091446
#
#          iv      oi  stockPrice        day ticker
# 0  0.091148  4981.0      469.69 2024-01-05    SPY
#
# [1 rows x 21 columns]
# Exposure is : 200676.7408
# Qty to sell is 7
#   ✅ 2024-01-05: SCALED IN by selling 7 contracts of strike 471.0
# Processing timestamp  2024-01-05 10:30:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-01-08   471.0    4           1 2024-01-05 15:30:00  0.935  0.935
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  0.935  0.935    30.0  ...    415.0      0.93      0.94  0.087283  0.087905
#
#          iv      oi  stockPrice        day ticker
# 0  0.087594  4981.0       469.5 2024-01-05    SPY
#
# [1 rows x 21 columns]
# Exposure is : 602334.7833001709
# Qty to sell is 21
#   ✅ 2024-01-05: SCALED IN by selling 21 contracts of strike 471.0
#    Expiring position with strike 471.0 on 2024-01-08
#    Found 3 prices in closing window. Avg exit price: $3.58
# Pnl of hedge was -1763.9999999999998
#    Expiring position with strike 471.0 on 2024-01-08
#    Found 3 prices in closing window. Avg exit price: $3.58
# Pnl of hedge was -5564.999999999999
#   ⚠️ 2024-01-08: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-01-09: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-01-09: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-01-09: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-01-10: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-01-16: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-01-18 11:00:00
#   ⚠️ 2024-01-18: No options data found for this entry signal.
#   ⚠️ 2024-01-18: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-01-19: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-01-19 10:15:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-01-22   479.0    4           1 2024-01-19 15:15:00  0.945  0.945
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  0.945  0.945   326.0  ...    251.0      0.94      0.95  0.090143  0.090729
#
#          iv      oi  stockPrice        day ticker
# 0  0.090436  5411.0      477.31 2024-01-19    SPY
#
# [1 rows x 21 columns]
# Exposure is : 600129.962032898
# Qty to sell is 21
#   ✅ 2024-01-19: SCALED IN by selling 21 contracts of strike 479.0
#    Expiring position with strike 479.0 on 2024-01-22
#    Found 3 prices in closing window. Avg exit price: $4.66
# Pnl of hedge was -7812.0
#   ⚠️ 2024-01-22: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-01-22: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-01-22: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-01-22: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-02-02 11:00:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-02-05   494.0    4           1 2024-02-02 16:00:00  0.945  0.945
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv   askIv  \
# 0  0.945  0.945    56.0  ...    152.0      0.94      0.95  0.091574  0.0922
#
#          iv      oi  stockPrice        day ticker
# 0  0.091887  5620.0      492.15 2024-02-02    SPY
#
# [1 rows x 21 columns]
# Exposure is : 298906.3992614746
# Qty to sell is 10
#   ✅ 2024-02-02: SCALED IN by selling 10 contracts of strike 494.0
# Processing timestamp  2024-02-02 11:15:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-02-05   494.0    4           1 2024-02-02 16:15:00  1.015  1.015
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.015  1.015    81.0  ...    374.0      1.01      1.02  0.092156  0.092755
#
#          iv      oi  stockPrice        day ticker
# 0  0.092456  5620.0      492.38 2024-02-02    SPY
#
# [1 rows x 21 columns]
# Exposure is : 600338.8187353516
# Qty to sell is 20
#   ✅ 2024-02-02: SCALED IN by selling 20 contracts of strike 494.0
#    Expiring position with strike 494.0 on 2024-02-05
#    Found 3 prices in closing window. Avg exit price: $0.03
# Pnl of hedge was 910.0
#    Expiring position with strike 494.0 on 2024-02-05
#    Found 3 prices in closing window. Avg exit price: $0.03
# Pnl of hedge was 1960.0000000000002
#   ⚠️ 2024-02-05: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-02-05: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-02-05: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-02-05: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-02-06: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-02-06 09:45:00
#   ⚠️ 2024-02-06: No options data found for this entry signal.
#   ⚠️ 2024-02-06: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-02-14 10:15:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-02-15   498.0    2           1 2024-02-14 15:15:00  1.265  1.265
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.265  1.265    68.0  ...    193.0      1.26      1.27  0.142142  0.143017
#
#         iv      oi  stockPrice        day ticker
# 0  0.14258  5818.0      496.85 2024-02-14    SPY
#
# [1 rows x 21 columns]
# Exposure is : 502458.6568128052
# Qty to sell is 17
#   ✅ 2024-02-14: SCALED IN by selling 17 contracts of strike 498.0
# Processing timestamp  2024-02-14 10:30:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-02-15   499.0    2           1 2024-02-14 15:30:00  1.095  1.095
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.095  1.095   141.0  ...     68.0      1.09       1.1  0.133676  0.134575
#
#          iv      oi  stockPrice        day ticker
# 0  0.134125  3989.0      497.68 2024-02-14    SPY
#
# [1 rows x 21 columns]
# Exposure is : 599828.3866846558
# Qty to sell is 20
#   ✅ 2024-02-14: SCALED IN by selling 20 contracts of strike 499.0
#    Expiring position with strike 498.0 on 2024-02-15
#    Found 3 prices in closing window. Avg exit price: $3.83
# Pnl of hedge was -4369.000000000001
#    Expiring position with strike 499.0 on 2024-02-15
#    Found 3 prices in closing window. Avg exit price: $2.82
# Pnl of hedge was -3453.3333333333326
#   ⚠️ 2024-02-15: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-02-15: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-02-15: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-02-16 11:45:00
#   ⚠️ 2024-02-16: No options data found for this entry signal.
# Processing timestamp  2024-02-16 12:00:00
#   ⚠️ 2024-02-16: No options data found for this entry signal.
#   ⚠️ 2024-02-20: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-02-20: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-02-20: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-02-21: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-02-22: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-02-22 10:15:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-02-23   507.0    2           1 2024-02-22 15:15:00  0.915  0.915
# 1 2024-02-23   506.0    2           1 2024-02-22 15:15:00  1.275  1.275
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  0.915  0.915   177.0  ...    282.0      0.91      0.92  0.151241  0.152170
# 1  1.275  1.275   924.0  ...    176.0      1.27      1.28  0.151625  0.152496
#
#          iv       oi  stockPrice        day ticker
# 0  0.151705  10017.0      504.77 2024-02-22    SPY
# 1  0.152061   7391.0      504.77 2024-02-22    SPY
#
# [2 rows x 21 columns]
# Exposure is : 604075.6839904785
# Qty to sell is 20
#   ✅ 2024-02-22: SCALED IN by selling 20 contracts of strike 507.0
#    Expiring position with strike 507.0 on 2024-02-23
#    Found 3 prices in closing window. Avg exit price: $1.46
# Pnl of hedge was -1106.6666666666672
# Processing timestamp  2024-02-23 11:45:00
#   ⚠️ 2024-02-23: No options data found for this entry signal.
#   ⚠️ 2024-02-26: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-02-26: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-02-28: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-02-29: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-03-01 09:30:00
#   ⚠️ 2024-03-01: No options data found for this entry signal.
#   ⚠️ 2024-03-01: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-03-05: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-03-06 11:15:00
#   ⚠️ 2024-03-06: No options data found for this entry signal.
# Processing timestamp  2024-03-06 11:30:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-03-07   513.0    2           1 2024-03-06 16:30:00  0.985  0.985
#
#     open  close  volume  ...  askSize  bidPrice  askPrice    bidIv     askIv  \
# 0  0.985  0.985   263.0  ...    223.0      0.98      0.99  0.13576  0.136726
#
#          iv      oi  stockPrice        day ticker
# 0  0.136243  3968.0      511.35 2024-03-06    SPY
#
# [1 rows x 21 columns]
# Exposure is : 597645.3776550293
# Qty to sell is 19
#   ✅ 2024-03-06: SCALED IN by selling 19 contracts of strike 513.0
#    Expiring position with strike 513.0 on 2024-03-07
#    Found 3 prices in closing window. Avg exit price: $2.19
# Pnl of hedge was -2299.0
#   ⚠️ 2024-03-07: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-03-08 10:00:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-03-11   519.0    4           1 2024-03-08 15:00:00  1.265  1.265
#
#     open  close  volume  ...  askSize  bidPrice  askPrice    bidIv     askIv  \
# 0  1.265  1.265   346.0  ...     67.0      1.26      1.27  0.09214  0.092662
#
#          iv      oi  stockPrice        day ticker
# 0  0.092401  6481.0      517.73 2024-03-08    SPY
#
# [1 rows x 21 columns]
# Exposure is : 504009.50726434326
# Qty to sell is 16
#   ✅ 2024-03-08: SCALED IN by selling 16 contracts of strike 519.0
# Processing timestamp  2024-03-08 10:15:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-03-11   520.0    4           1 2024-03-08 15:15:00  0.975  0.975
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  0.975  0.975   678.0  ...      2.0      0.97      0.98  0.090315  0.090881
#
#          iv      oi  stockPrice        day ticker
# 0  0.090598  5211.0      518.07 2024-03-08    SPY
#
# [1 rows x 21 columns]
# Exposure is : 600471.5503292846
# Qty to sell is 19
#   ✅ 2024-03-08: SCALED IN by selling 19 contracts of strike 520.0
# Processing timestamp  2024-03-08 12:45:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-03-11   516.0    4           1 2024-03-08 17:45:00  1.035  1.035
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv    askIv  \
# 0  1.035  1.035   115.0  ...     76.0      1.03      1.04  0.090411  0.09095
#
#         iv      oi  stockPrice        day ticker
# 0  0.09068  4533.0      514.24 2024-03-08    SPY
#
# [1 rows x 21 columns]
# Exposure is : 391972.3454623413
# Qty to sell is 13
#   ✅ 2024-03-08: SCALED IN by selling 13 contracts of strike 516.0
#    Expiring position with strike 519.0 on 2024-03-11
#    Found 3 prices in closing window. Avg exit price: $0.01
# Pnl of hedge was 2000.0
#    Expiring position with strike 520.0 on 2024-03-11
#    Found 3 prices in closing window. Avg exit price: $0.01
# Pnl of hedge was 1823.9999999999998
#    Expiring position with strike 516.0 on 2024-03-11
#    Found 3 prices in closing window. Avg exit price: $0.01
# Pnl of hedge was 1326.0
#   ⚠️ 2024-03-11: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-03-11: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-03-11 14:00:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-03-12   514.0    2           1 2024-03-11 18:00:00  1.175  1.175
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.175  1.175    62.0  ...    217.0      1.17      1.18  0.206901  0.207929
#
#          iv      oi  stockPrice        day ticker
# 0  0.207415  5240.0      511.06 2024-03-11    SPY
#
# [1 rows x 21 columns]
# Exposure is : 105851.57
# Qty to sell is 3
#   ✅ 2024-03-11: SCALED IN by selling 3 contracts of strike 514.0
#    Expiring position with strike 514.0 on 2024-03-12
#    Found 3 prices in closing window. Avg exit price: $3.21
# Pnl of hedge was -611.0
# Processing timestamp  2024-03-12 10:15:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-03-13   515.0    2           1 2024-03-12 14:15:00  1.205  1.205
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.205  1.205   143.0  ...    106.0       1.2      1.21  0.152821  0.153677
#
#          iv      oi  stockPrice        day ticker
# 0  0.153249  7971.0       513.5 2024-03-12    SPY
#
# [1 rows x 21 columns]
# Exposure is : 603048.6746502685
# Qty to sell is 20
#   ✅ 2024-03-12: SCALED IN by selling 20 contracts of strike 515.0
#    Expiring position with strike 515.0 on 2024-03-13
#    Found 3 prices in closing window. Avg exit price: $1.11
# Pnl of hedge was 186.66666666666654
#   ⚠️ 2024-03-13: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-03-13: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-03-14: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-03-18: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-03-19 11:15:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-03-20   515.0    2           1 2024-03-19 15:15:00  1.155  1.155
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.155  1.155    72.0  ...    395.0      1.15      1.16  0.178833  0.179765
#
#          iv      oi  stockPrice        day ticker
# 0  0.179299  7686.0      512.61 2024-03-19    SPY
#
# [1 rows x 21 columns]
# Exposure is : 196604.82
# Qty to sell is 6
#   ✅ 2024-03-19: SCALED IN by selling 6 contracts of strike 515.0
#    Expiring position with strike 515.0 on 2024-03-20
#    Found 3 prices in closing window. Avg exit price: $5.20
# Pnl of hedge was -2428.0
#   ⚠️ 2024-03-21: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-03-21: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-03-21 11:00:00
#   ⚠️ 2024-03-21: No options data found for this entry signal.
#   ⚠️ 2024-03-22: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-03-26: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-04-04 12:30:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-04-05   525.0    2           1 2024-04-04 16:30:00  0.955  0.955
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  0.955  0.955    59.0  ...    196.0      0.95      0.96  0.132261  0.133157
#
#          iv       oi  stockPrice        day ticker
# 0  0.132709  35589.0       523.5 2024-04-04    SPY
#
# [1 rows x 21 columns]
# Exposure is : 100063.6905
# Qty to sell is 3
#   ✅ 2024-04-04: SCALED IN by selling 3 contracts of strike 525.0
#    Expiring position with strike 525.0 on 2024-04-05
#    Found 3 prices in closing window. Avg exit price: $0.01
# Pnl of hedge was 282.0
# Processing timestamp  2024-04-05 11:15:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-04-08   520.0    4           1 2024-04-05 15:15:00  1.025  1.025
# 1 2024-04-08   519.0    4           1 2024-04-05 15:15:00  1.415  1.415
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.025  1.025   135.0  ...    116.0      1.02      1.03  0.108409  0.108975
# 1  1.415  1.415   433.0  ...     51.0      1.41      1.42  0.111335  0.111865
#
#          iv      oi  stockPrice        day ticker
# 0  0.108692  8311.0      517.21 2024-04-05    SPY
# 1  0.111600  5104.0      517.21 2024-04-05    SPY
#
# [2 rows x 21 columns]
# Exposure is : 196412.751
# Qty to sell is 6
#   ✅ 2024-04-05: SCALED IN by selling 6 contracts of strike 520.0
#    Expiring position with strike 520.0 on 2024-04-08
#    Found 3 prices in closing window. Avg exit price: $0.01
# Pnl of hedge was 606.0
# Processing timestamp  2024-04-08 10:45:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-04-09   521.0    2           1 2024-04-08 14:45:00  1.005  1.005
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv    askIv  \
# 0  1.005  1.005   206.0  ...    308.0       1.0      1.01  0.127378  0.12823
#
#          iv      oi  stockPrice        day ticker
# 0  0.127804  4276.0      519.71 2024-04-08    SPY
#
# [1 rows x 21 columns]
# Exposure is : 300161.8763916016
# Qty to sell is 10
#   ✅ 2024-04-08: SCALED IN by selling 10 contracts of strike 521.0
# Processing timestamp  2024-04-08 11:15:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-04-09   521.0    2           1 2024-04-08 15:15:00  0.975  0.975
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv    askIv  \
# 0  0.975  0.975   304.0  ...    147.0      0.97      0.98  0.127079  0.12794
#
#          iv      oi  stockPrice        day ticker
# 0  0.127509  4276.0      519.67 2024-04-08    SPY
#
# [1 rows x 21 columns]
# Exposure is : 600437.07159729
# Qty to sell is 19
#   ✅ 2024-04-08: SCALED IN by selling 19 contracts of strike 521.0
#    Expiring position with strike 521.0 on 2024-04-09
#    Found 3 prices in closing window. Avg exit price: $0.01
# Pnl of hedge was 990.0
#    Expiring position with strike 521.0 on 2024-04-09
#    Found 3 prices in closing window. Avg exit price: $0.01
# Pnl of hedge was 1823.9999999999998
#   ⚠️ 2024-04-09: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-04-09: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-04-10 09:45:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-04-11   518.0    2           1 2024-04-10 13:45:00  0.925  0.925
# 1 2024-04-11   517.0    2           1 2024-04-10 13:45:00  1.250  1.250
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  0.925  0.925    84.0  ...    100.0      0.92      0.93  0.192241  0.193386
# 1  1.250  1.250   239.0  ...    253.0      1.24      1.26  0.195329  0.197318
#
#          iv      oi  stockPrice        day ticker
# 0  0.192814  4431.0       514.0 2024-04-10    SPY
# 1  0.196323  3119.0       514.0 2024-04-10    SPY
#
# [2 rows x 21 columns]
# Exposure is : 302971.8532409668
# Qty to sell is 10
#   ✅ 2024-04-10: SCALED IN by selling 10 contracts of strike 518.0
#    Expiring position with strike 518.0 on 2024-04-11
#    Found 3 prices in closing window. Avg exit price: $0.62
# Pnl of hedge was 296.66666666666663
#   ⚠️ 2024-04-11: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-04-11: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-04-15: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-04-15 12:30:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-04-16   514.0    2           1 2024-04-15 16:30:00  1.050  1.050
# 1 2024-04-16   513.0    2           1 2024-04-15 16:30:00  1.415  1.415
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.050  1.050   340.0  ...    152.0      1.04      1.06  0.200051  0.202046
# 1  1.415  1.415    48.0  ...     52.0      1.41      1.42  0.205143  0.206091
#
#          iv      oi  stockPrice        day ticker
# 0  0.201049  2700.0      510.64 2024-04-15    SPY
# 1  0.205617  3585.0      510.64 2024-04-15    SPY
#
# [2 rows x 21 columns]
# Exposure is : 498540.410458374
# Qty to sell is 16
#   ✅ 2024-04-15: SCALED IN by selling 16 contracts of strike 514.0
#    Expiring position with strike 514.0 on 2024-04-16
#    Found 3 prices in closing window. Avg exit price: $0.01
# Pnl of hedge was 1648.0
#   ⚠️ 2024-04-16: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-04-17: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-04-18: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-04-18 11:00:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-04-19   506.0    2           1 2024-04-18 15:00:00  1.185  1.185
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.185  1.185   212.0  ...    251.0      1.18      1.19  0.193842  0.194789
#
#          iv       oi  stockPrice        day ticker
# 0  0.194315  12343.0       503.3 2024-04-18    SPY
#
# [1 rows x 21 columns]
# Exposure is : 100390.72692489624
# Qty to sell is 3
#   ✅ 2024-04-18: SCALED IN by selling 3 contracts of strike 506.0
# Processing timestamp  2024-04-18 11:15:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-04-19   506.0    2           1 2024-04-18 15:15:00  1.205  1.205
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.205  1.205    16.0  ...     98.0       1.2      1.21  0.190454  0.191405
#
#         iv       oi  stockPrice        day ticker
# 0  0.19093  12343.0      503.51 2024-04-18    SPY
#
# [1 rows x 21 columns]
# Exposure is : 200051.8691213989
# Qty to sell is 7
#   ✅ 2024-04-18: SCALED IN by selling 7 contracts of strike 506.0
# Processing timestamp  2024-04-18 12:15:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-04-19   505.0    2           1 2024-04-18 16:15:00  1.080  1.080
# 1 2024-04-19   504.0    2           1 2024-04-18 16:15:00  1.455  1.455
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.080  1.080   121.0  ...    417.0      1.07      1.09  0.187338  0.189273
# 1  1.455  1.455    49.0  ...    167.0      1.45      1.46  0.190517  0.191451
#
#          iv       oi  stockPrice        day ticker
# 0  0.188306  34890.0      502.32 2024-04-18    SPY
# 1  0.190984   7103.0      502.32 2024-04-18    SPY
#
# [2 rows x 21 columns]
# Exposure is : 299396.30261642457
# Qty to sell is 10
#   ✅ 2024-04-18: SCALED IN by selling 10 contracts of strike 505.0
#    Expiring position with strike 506.0 on 2024-04-19
#    Found 3 prices in closing window. Avg exit price: $0.01
# Pnl of hedge was 351.0
#    Expiring position with strike 506.0 on 2024-04-19
#    Found 3 prices in closing window. Avg exit price: $0.01
# Pnl of hedge was 833.0
#    Expiring position with strike 505.0 on 2024-04-19
#    Found 3 prices in closing window. Avg exit price: $0.01
# Pnl of hedge was 1060.0000000000002
#   ⚠️ 2024-04-22: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-04-22 12:15:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-04-23   500.0    2           1 2024-04-22 16:15:00  1.015  1.015
# 1 2024-04-23   499.0    2           1 2024-04-22 16:15:00  1.405  1.405
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.015  1.015   123.0  ...    247.0      1.01      1.02  0.169024  0.170051
# 1  1.405  1.405    78.0  ...    101.0      1.40      1.41  0.171545  0.172461
#
#          iv      oi  stockPrice        day ticker
# 0  0.169537  5266.0      497.77 2024-04-22    SPY
# 1  0.172003  2424.0      497.77 2024-04-22    SPY
#
# [2 rows x 21 columns]
# Exposure is : 298414.6390606995
# Qty to sell is 10
#   ✅ 2024-04-22: SCALED IN by selling 10 contracts of strike 500.0
# Processing timestamp  2024-04-22 12:30:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-04-23   500.0    2           1 2024-04-22 16:30:00  0.995  0.995
# 1 2024-04-23   499.0    2           1 2024-04-22 16:30:00  1.385  1.385
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  0.995  0.995    35.0  ...     97.0      0.99      1.00  0.168191  0.169172
# 1  1.385  1.385    35.0  ...    119.0      1.38      1.39  0.170930  0.171850
#
#          iv      oi  stockPrice        day ticker
# 0  0.168682  5266.0      497.74 2024-04-22    SPY
# 1  0.171390  2424.0      497.74 2024-04-22    SPY
#
# [2 rows x 21 columns]
# Exposure is : 497014.73872818
# Qty to sell is 17
#   ✅ 2024-04-22: SCALED IN by selling 17 contracts of strike 500.0
#    Expiring position with strike 500.0 on 2024-04-23
#    Found 3 prices in closing window. Avg exit price: $5.29
# Pnl of hedge was -4276.666666666667
#    Expiring position with strike 500.0 on 2024-04-23
#    Found 3 prices in closing window. Avg exit price: $5.29
# Pnl of hedge was -7304.333333333332
#   ⚠️ 2024-04-23: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-04-23 10:15:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-04-24   506.0    2           1 2024-04-23 14:15:00  0.975  0.975
# 1 2024-04-24   505.0    2           1 2024-04-23 14:15:00  1.335  1.335
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  0.975  0.975   136.0  ...     86.0      0.97      0.98  0.171797  0.172780
# 1  1.335  1.335   418.0  ...      8.0      1.33      1.34  0.173995  0.174897
#
#          iv       oi  stockPrice        day ticker
# 0  0.172288   2929.0      503.32 2024-04-23    SPY
# 1  0.174446  10017.0      503.32 2024-04-23    SPY
#
# [2 rows x 21 columns]
# Exposure is : 508595.77198349
# Qty to sell is 17
#   ✅ 2024-04-23: SCALED IN by selling 17 contracts of strike 506.0
# Processing timestamp  2024-04-23 10:30:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-04-24   507.0    2           1 2024-04-23 14:30:00  0.965  0.965
# 1 2024-04-24   506.0    2           1 2024-04-23 14:30:00  1.335  1.335
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  0.965  0.965   145.0  ...     76.0      0.96      0.97  0.170999  0.172059
# 1  1.335  1.335   180.0  ...     67.0      1.33      1.34  0.174154  0.175094
#
#          iv      oi  stockPrice        day ticker
# 0  0.171529  2561.0      504.35 2024-04-23    SPY
# 1  0.174624  2929.0      504.35 2024-04-23    SPY
#
# [2 rows x 21 columns]
# Exposure is : 608775.9988468933
# Qty to sell is 20
#   ✅ 2024-04-23: SCALED IN by selling 20 contracts of strike 507.0
#    Expiring position with strike 506.0 on 2024-04-24
#    Found 3 prices in closing window. Avg exit price: $0.56
# Pnl of hedge was 702.6666666666666
#    Expiring position with strike 507.0 on 2024-04-24
#    Found 3 prices in closing window. Avg exit price: $0.20
# Pnl of hedge was 1513.3333333333333
#   ⚠️ 2024-04-24: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-04-25: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-04-25: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-04-26 10:00:00
# Found data of options as       expiry  strike  dte  optionType                  ts   low  high  open  \
# 0 2024-04-29   510.0    4           1 2024-04-26 14:00:00  1.18  1.18  1.18
#
#    close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0   1.18   170.0  ...    142.0      1.17      1.19  0.105809  0.106912
#
#          iv      oi  stockPrice        day ticker
# 0  0.106361  4117.0       507.9 2024-04-26    SPY
#
# [1 rows x 21 columns]
# Exposure is : 298498.52280349727
# Qty to sell is 10
#   ✅ 2024-04-26: SCALED IN by selling 10 contracts of strike 510.0
# Processing timestamp  2024-04-26 10:15:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-04-29   511.0    4           1 2024-04-26 14:15:00  1.035  1.035
# 1 2024-04-29   510.0    4           1 2024-04-26 14:15:00  1.450  1.450
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.035  1.035    58.0  ...     20.0      1.03      1.04  0.099235  0.099805
# 1  1.450  1.450   429.0  ...    200.0      1.44      1.46  0.101540  0.102610
#
#          iv       oi  stockPrice        day ticker
# 0  0.099520  14944.0      508.77 2024-04-26    SPY
# 1  0.102075   4117.0      508.77 2024-04-26    SPY
#
# [2 rows x 21 columns]
# Exposure is : 596614.5033760987
# Qty to sell is 20
#   ✅ 2024-04-26: SCALED IN by selling 20 contracts of strike 511.0
#    Expiring position with strike 510.0 on 2024-04-29
#    Found 3 prices in closing window. Avg exit price: $0.11
# Pnl of hedge was 1056.6666666666667
#    Expiring position with strike 511.0 on 2024-04-29
#    Found 3 prices in closing window. Avg exit price: $0.01
# Pnl of hedge was 2039.9999999999998
#   ⚠️ 2024-04-29: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-04-30: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-05-01 09:30:00
#   ⚠️ 2024-05-01: No options data found for this entry signal.
# Processing timestamp  2024-05-02 11:30:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-05-03   506.0    2           1 2024-05-02 15:30:00  1.125  1.125
# 1 2024-05-03   505.0    2           1 2024-05-02 15:30:00  1.455  1.455
#
#     open  close  volume  ...  askSize  bidPrice  askPrice    bidIv     askIv  \
# 0  1.125  1.125    32.0  ...    152.0      1.12      1.13  0.22485  0.225852
# 1  1.455  1.455   208.0  ...    183.0      1.45      1.46  0.22742  0.228377
#
#          iv       oi  stockPrice        day ticker
# 0  0.225351   5309.0      502.11 2024-05-02    SPY
# 1  0.227898  12872.0      502.11 2024-05-02    SPY
#
# [2 rows x 21 columns]
# Exposure is : 399228.578605957
# Qty to sell is 13
#   ✅ 2024-05-02: SCALED IN by selling 13 contracts of strike 506.0
# Processing timestamp  2024-05-02 11:45:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-05-03   507.0    2           1 2024-05-02 15:45:00  0.925  0.925
# 1 2024-05-03   506.0    2           1 2024-05-02 15:45:00  1.205  1.205
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  0.925  0.925    34.0  ...    467.0      0.92      0.93  0.228403  0.229544
# 1  1.205  1.205    15.0  ...    300.0      1.20      1.21  0.230575  0.231581
#
#          iv      oi  stockPrice        day ticker
# 0  0.228973  6059.0      502.24 2024-05-02    SPY
# 1  0.231078  5309.0      502.24 2024-05-02    SPY
#
# [2 rows x 21 columns]
# Exposure is : 600284.0748254395
# Qty to sell is 20
#   ✅ 2024-05-02: SCALED IN by selling 20 contracts of strike 507.0
#    Expiring position with strike 506.0 on 2024-05-03
#    Found 3 prices in closing window. Avg exit price: $5.49
# Pnl of hedge was -5685.333333333333
#    Expiring position with strike 507.0 on 2024-05-03
#    Found 3 prices in closing window. Avg exit price: $4.44
# Pnl of hedge was -7040.000000000001
#   ⚠️ 2024-05-03: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-05-03 10:00:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-05-06   514.0    4           1 2024-05-03 14:00:00  0.995  0.995
# 1 2024-05-06   513.0    4           1 2024-05-03 14:00:00  1.390  1.390
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  0.995  0.995   213.0  ...     46.0      0.99       1.0  0.101288  0.101857
# 1  1.390  1.390   464.0  ...     64.0      1.38       1.4  0.103492  0.104558
#
#          iv      oi  stockPrice        day ticker
# 0  0.101572  2764.0      511.56 2024-05-03    SPY
# 1  0.104025  1560.0      511.56 2024-05-03    SPY
#
# [2 rows x 21 columns]
# Exposure is : 605148.0332952881
# Qty to sell is 20
#   ✅ 2024-05-03: SCALED IN by selling 20 contracts of strike 514.0
#    Expiring position with strike 514.0 on 2024-05-06
#    Found 3 prices in closing window. Avg exit price: $2.36
# Pnl of hedge was -2746.6666666666665
#   ⚠️ 2024-05-06: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-05-06: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-05-06: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-05-07: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-05-09: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-05-15 11:15:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-05-16   529.0    2           1 2024-05-15 15:15:00  1.005  1.005
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.005  1.005    81.0  ...    390.0       1.0      1.01  0.115845  0.116702
#
#          iv      oi  stockPrice        day ticker
# 0  0.116273  1882.0      527.88 2024-05-15    SPY
#
# [1 rows x 21 columns]
# Exposure is : 100035.71926116943
# Qty to sell is 3
#   ✅ 2024-05-15: SCALED IN by selling 3 contracts of strike 529.0
# Processing timestamp  2024-05-15 11:30:00
#   ⚠️ 2024-05-15: No options data found for this entry signal.
# Processing timestamp  2024-05-15 11:45:00
#   ⚠️ 2024-05-15: No options data found for this entry signal.
# Processing timestamp  2024-05-15 12:00:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-05-16   529.0    2           1 2024-05-15 16:00:00  1.015  1.015
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.015  1.015    12.0  ...    144.0      1.01      1.02  0.116561  0.117434
#
#          iv      oi  stockPrice        day ticker
# 0  0.116997  1882.0      527.91 2024-05-15    SPY
#
# [1 rows x 21 columns]
# Exposure is : 400081.9178390503
# Qty to sell is 13
#   ✅ 2024-05-15: SCALED IN by selling 13 contracts of strike 529.0
#    Expiring position with strike 529.0 on 2024-05-16
#    Found 3 prices in closing window. Avg exit price: $0.40
# Pnl of hedge was 180.00000000000003
#    Expiring position with strike 529.0 on 2024-05-16
#    Found 3 prices in closing window. Avg exit price: $0.40
# Pnl of hedge was 793.0000000000001
#   ⚠️ 2024-05-16: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-05-20: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-05-20: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-05-23 12:15:00
#   ⚠️ 2024-05-23: No options data found for this entry signal.
#   ⚠️ 2024-05-23: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-05-23: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-05-23: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-05-24 11:30:00
#   ⚠️ 2024-05-24: No options data found for this entry signal.
# Processing timestamp  2024-05-24 11:45:00
#   ⚠️ 2024-05-24: No options data found for this entry signal.
# Processing timestamp  2024-05-24 12:00:00
#   ⚠️ 2024-05-24: No options data found for this entry signal.
#   ⚠️ 2024-05-24: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-05-30: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-05-30 12:30:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-05-31   526.0    2           1 2024-05-30 16:30:00  0.945  0.945
#
#     open  close  volume  ...  askSize  bidPrice  askPrice    bidIv     askIv  \
# 0  0.945  0.945    76.0  ...    237.0      0.94      0.95  0.13988  0.140793
#
#          iv      oi  stockPrice        day ticker
# 0  0.140336  8825.0      524.04 2024-05-30    SPY
#
# [1 rows x 21 columns]
# Exposure is : 201553.91455078125
# Qty to sell is 6
#   ✅ 2024-05-30: SCALED IN by selling 6 contracts of strike 526.0
#    Expiring position with strike 526.0 on 2024-05-31
#    Found 3 prices in closing window. Avg exit price: $0.66
# Pnl of hedge was 167.99999999999994
#   ⚠️ 2024-06-03: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-06-05 11:30:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-06-06   533.0    2           1 2024-06-05 15:30:00  1.035  1.035
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.035  1.035    72.0  ...    293.0      1.03      1.04  0.122459  0.123329
#
#          iv      oi  stockPrice        day ticker
# 0  0.122894  4270.0       531.9 2024-06-05    SPY
#
# [1 rows x 21 columns]
# Exposure is : 201199.1704215088
# Qty to sell is 6
#   ✅ 2024-06-05: SCALED IN by selling 6 contracts of strike 533.0
# Processing timestamp  2024-06-05 12:00:00
#   ⚠️ 2024-06-05: No options data found for this entry signal.
# Processing timestamp  2024-06-05 12:15:00
#   ⚠️ 2024-06-05: No options data found for this entry signal.
#    Expiring position with strike 533.0 on 2024-06-06
#    Found 3 prices in closing window. Avg exit price: $1.43
# Pnl of hedge was -239.99999999999994
#   ⚠️ 2024-06-06: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-06-07: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-06-10: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-06-12 10:00:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-06-13   545.0    2           1 2024-06-12 14:00:00  1.225  1.225
# 1 2024-06-12   544.0    1           1 2024-06-12 14:00:00  1.125  1.125
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.225  1.225    45.0  ...    569.0      1.22      1.23  0.171801  0.172632
# 1  1.125  1.125   279.0  ...    127.0      1.12      1.13  0.302562  0.304372
#
#          iv      oi  stockPrice        day ticker
# 0  0.172216  2986.0      542.63 2024-06-12    SPY
# 1  0.303467  5908.0      542.63 2024-06-12    SPY
#
# [2 rows x 21 columns]
# Exposure is : 600536.8818511963
# Qty to sell is 18
#   ✅ 2024-06-12: SCALED IN by selling 18 contracts of strike 545.0
#    Expiring position with strike 545.0 on 2024-06-13
#    Found 3 prices in closing window. Avg exit price: $0.01
# Pnl of hedge was 2178.0
# Processing timestamp  2024-06-13 09:30:00
#   ⚠️ 2024-06-13: No options data found for this entry signal.
#   ⚠️ 2024-06-13: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-06-14: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-06-17: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-06-17: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-06-20: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-06-21 11:45:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-06-24   546.0    4           1 2024-06-21 15:45:00  0.945  0.945
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  0.945  0.945    33.0  ...    314.0      0.94      0.95  0.072525  0.073064
#
#          iv      oi  stockPrice        day ticker
# 0  0.072795  1997.0      544.67 2024-06-21    SPY
#
# [1 rows x 21 columns]
# Exposure is : -96393.22
# Qty to sell is -3
# Processing timestamp  2024-06-21 13:00:00
#   ⚠️ 2024-06-21: No options data found for this entry signal.
# Processing timestamp  2024-06-25 12:15:00
#   ⚠️ 2024-06-25: No options data found for this entry signal.
#   ⚠️ 2024-06-27: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-07-11: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-07-11: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-07-12 10:15:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-07-15   561.0    4           1 2024-07-12 14:15:00  0.975  0.975
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv   askIv  \
# 0  0.975  0.975   247.0  ...    120.0      0.97      0.98  0.073775  0.0743
#
#          iv      oi  stockPrice        day ticker
# 0  0.074038  4460.0      559.64 2024-07-12    SPY
#
# [1 rows x 21 columns]
# Exposure is : -198385.61631589357
# Qty to sell is -6
# Processing timestamp  2024-07-12 10:45:00
#   ⚠️ 2024-07-12: No options data found for this entry signal.
# Processing timestamp  2024-07-12 11:30:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-07-15   563.0    4           1 2024-07-12 15:30:00  0.925  0.925
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  0.925  0.925  1131.0  ...    115.0      0.92      0.93  0.068478  0.068998
#
#          iv      oi  stockPrice        day ticker
# 0  0.068738  5893.0      561.71 2024-07-12    SPY
#
# [1 rows x 21 columns]
# Exposure is : -4937.50599680176
# Qty to sell is 0
# Processing timestamp  2024-07-12 12:00:00
#   ⚠️ 2024-07-12: No options data found for this entry signal.
# Processing timestamp  2024-07-12 12:15:00
#   ⚠️ 2024-07-12: No options data found for this entry signal.
# Processing timestamp  2024-07-12 14:00:00
#   ⚠️ 2024-07-12: No options data found for this entry signal.
#   ⚠️ 2024-07-15: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-07-16: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-07-16: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-07-17: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-07-17: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-07-18 10:15:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-07-19   562.0    2           1 2024-07-18 14:15:00  0.925  0.925
# 1 2024-07-19   561.0    2           1 2024-07-18 14:15:00  1.275  1.275
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  0.925  0.925    47.0  ...    279.0      0.92      0.93  0.151408  0.152282
# 1  1.275  1.275    30.0  ...    333.0      1.27      1.28  0.153113  0.153918
#
#          iv       oi  stockPrice        day ticker
# 0  0.151845  42055.0      559.16 2024-07-18    SPY
# 1  0.153515  12641.0      559.16 2024-07-18    SPY
#
# [2 rows x 21 columns]
# Exposure is : 300719.0117706299
# Qty to sell is 9
#   ✅ 2024-07-18: SCALED IN by selling 9 contracts of strike 562.0
# Processing timestamp  2024-07-18 10:30:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-07-19   561.0    2           1 2024-07-18 14:30:00  1.125  1.125
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.125  1.125   532.0  ...    340.0      1.12      1.13  0.149737  0.150543
#
#         iv       oi  stockPrice        day ticker
# 0  0.15014  12641.0      558.83 2024-07-18    SPY
#
# [1 rows x 21 columns]
# Exposure is : 599628.6020202637
# Qty to sell is 18
#   ✅ 2024-07-18: SCALED IN by selling 18 contracts of strike 561.0
#    Expiring position with strike 562.0 on 2024-07-19
#    Found 3 prices in closing window. Avg exit price: $0.01
# Pnl of hedge was 819.0
#    Expiring position with strike 561.0 on 2024-07-19
#    Found 3 prices in closing window. Avg exit price: $0.01
# Pnl of hedge was 1998.0
#   ⚠️ 2024-07-19: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-07-19: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-07-22: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-07-22 10:00:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-07-23   555.0    2           1 2024-07-22 14:00:00  1.165  1.165
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.165  1.165   219.0  ...    239.0      1.16      1.17  0.156838  0.157626
#
#          iv      oi  stockPrice        day ticker
# 0  0.157232  4224.0      552.73 2024-07-22    SPY
#
# [1 rows x 21 columns]
# Exposure is : 494252.8745880127
# Qty to sell is 15
#   ✅ 2024-07-22: SCALED IN by selling 15 contracts of strike 555.0
# Processing timestamp  2024-07-22 10:15:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-07-23   555.0    2           1 2024-07-22 14:15:00  1.015  1.015
# 1 2024-07-23   554.0    2           1 2024-07-22 14:15:00  1.395  1.395
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.015  1.015   356.0  ...    289.0      1.01      1.02  0.156658  0.157607
# 1  1.395  1.395  1655.0  ...    317.0      1.39      1.40  0.159565  0.160419
#
#          iv      oi  stockPrice        day ticker
# 0  0.157133  4224.0      552.43 2024-07-22    SPY
# 1  0.159992  4421.0      552.43 2024-07-22    SPY
#
# [2 rows x 21 columns]
# Exposure is : 596310.9516372681
# Qty to sell is 18
#   ✅ 2024-07-22: SCALED IN by selling 18 contracts of strike 555.0
#    Expiring position with strike 555.0 on 2024-07-23
#    Found 3 prices in closing window. Avg exit price: $0.27
# Pnl of hedge was 1340.0
#    Expiring position with strike 555.0 on 2024-07-23
#    Found 3 prices in closing window. Avg exit price: $0.27
# Pnl of hedge was 1338.0
#   ⚠️ 2024-07-24: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-07-24: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-07-25 11:15:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-07-26   548.0    2           1 2024-07-25 15:15:00  0.975  0.975
# 1 2024-07-26   547.0    2           1 2024-07-25 15:15:00  1.265  1.265
# 2 2024-07-25   545.0    1           1 2024-07-25 15:15:00  0.945  0.945
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  0.975  0.975    59.0  ...    514.0      0.97      0.98  0.197097  0.198200
# 1  1.265  1.265    82.0  ...    240.0      1.26      1.27  0.197448  0.198475
# 2  0.945  0.945  1043.0  ...    376.0      0.94      0.95  0.293932  0.296354
#
#          iv       oi  stockPrice        day ticker
# 0  0.197648   9813.0      543.73 2024-07-25    SPY
# 1  0.197961   9274.0      543.73 2024-07-25    SPY
# 2  0.295143  15035.0      543.73 2024-07-25    SPY
#
# [3 rows x 21 columns]
# Exposure is : 492251.86005096434
# Qty to sell is 15
#   ✅ 2024-07-25: SCALED IN by selling 15 contracts of strike 548.0
# Processing timestamp  2024-07-25 11:30:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-07-26   547.0    2           1 2024-07-25 15:30:00  1.165  1.165
# ...
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.105  1.105    97.0  ...    204.0       1.1      1.11  0.084551  0.085084
#
#          iv      oi  stockPrice        day ticker
# 0  0.084818  5010.0      553.46 2024-08-16    SPY
#
# [1 rows x 21 columns]
# Exposure is : 506681.8268072571
# Qty to sell is 15
#   ✅ 2024-08-16: SCALED IN by selling 15 contracts of strike 555.0
#    Expiring position with strike 555.0 on 2024-08-19
#    Found 3 prices in closing window. Avg exit price: $4.17
# Pnl of hedge was -4600.0
#   ⚠️ 2024-08-19: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-08-19: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-08-19: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-08-20: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-08-20: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-08-20: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-08-21 09:45:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-08-22   562.0    2           1 2024-08-21 13:45:00  1.205  1.205
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.205  1.205   308.0  ...    211.0       1.2      1.21  0.157137  0.157971
#
#          iv      oi  stockPrice        day ticker
# 0  0.157554  2250.0      559.86 2024-08-21    SPY
#
# [1 rows x 21 columns]
# Exposure is : -605636.474558728
# Qty to sell is -18
# Processing timestamp  2024-08-21 10:00:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-08-22   563.0    2           1 2024-08-21 14:00:00  0.975  0.975
# 1 2024-08-22   562.0    2           1 2024-08-21 14:00:00  1.375  1.375
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  0.975  0.975    81.0  ...     83.0      0.97      0.98  0.153045  0.153923
# 1  1.375  1.375    31.0  ...     93.0      1.37      1.38  0.158308  0.159114
#
#          iv      oi  stockPrice        day ticker
# 0  0.153484  2544.0      560.33 2024-08-21    SPY
# 1  0.158711  2250.0      560.33 2024-08-21    SPY
#
# [2 rows x 21 columns]
# Exposure is : -504845.7482739258
# Qty to sell is -15
# Processing timestamp  2024-08-21 10:15:00
# Found data of options as       expiry  strike  dte  optionType                  ts   low  high  open  \
# 0 2024-08-22   562.0    2           1 2024-08-21 14:15:00  1.08  1.08  1.08
# 1 2024-08-22   561.0    2           1 2024-08-21 14:15:00  1.46  1.46  1.46
#
#    close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0   1.08   350.0  ...    445.0      1.07      1.09  0.157885  0.159504
# 1   1.46   251.0  ...    107.0      1.45      1.47  0.160377  0.161923
#
#          iv      oi  stockPrice        day ticker
# 0  0.158695  2250.0      559.49 2024-08-21    SPY
# 1  0.161150  2567.0      559.49 2024-08-21    SPY
#
# [2 rows x 21 columns]
# Exposure is : -405083.7503939331
# Qty to sell is -12
# Processing timestamp  2024-08-21 11:45:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-08-22   562.0    2           1 2024-08-21 15:45:00  1.015  1.015
# 1 2024-08-22   561.0    2           1 2024-08-21 15:45:00  1.435  1.435
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.015  1.015    48.0  ...     92.0      1.01      1.02  0.148802  0.149665
# 1  1.435  1.435   174.0  ...    206.0      1.43      1.44  0.153607  0.154414
#
#          iv      oi  stockPrice        day ticker
# 0  0.149234  2250.0      559.79 2024-08-21    SPY
# 1  0.154011  2567.0      559.79 2024-08-21    SPY
#
# [2 rows x 21 columns]
# Exposure is : -202434.0961303711
# Qty to sell is -6
# Processing timestamp  2024-08-21 13:30:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-08-22   562.0    2           1 2024-08-21 17:30:00  1.005  1.005
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv    askIv  \
# 0  1.005  1.005     8.0  ...    232.0       1.0      1.01  0.144842  0.14573
#
#          iv      oi  stockPrice        day ticker
# 0  0.145286  2250.0      560.02 2024-08-21    SPY
#
# [1 rows x 21 columns]
# Exposure is : -101104.1332397461
# Qty to sell is -3
# Processing timestamp  2024-08-22 10:00:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-08-23   566.0    2           1 2024-08-22 14:00:00  1.005  1.005
# 1 2024-08-23   565.0    2           1 2024-08-22 14:00:00  1.375  1.375
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.005  1.005   139.0  ...    338.0      1.00      1.01  0.176626  0.177541
# 1  1.375  1.375   472.0  ...     31.0      1.37      1.38  0.181843  0.182670
#
#          iv       oi  stockPrice        day ticker
# 0  0.177083   4640.0      562.35 2024-08-22    SPY
# 1  0.182256  10778.0      562.35 2024-08-22    SPY
#
# [2 rows x 21 columns]
# Exposure is : 0.0
# Qty to sell is 0
#   ⚠️ 2024-08-22: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-08-23 10:30:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-08-26   565.0    4           1 2024-08-23 14:30:00  1.255  1.255
# 1 2024-08-23   564.0    1           1 2024-08-23 14:30:00  0.985  0.985
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.255  1.255   424.0  ...    116.0      1.25      1.26  0.100283  0.100803
# 1  0.985  0.985  1763.0  ...    148.0      0.98      0.99  0.261835  0.263713
#
#          iv       oi  stockPrice        day ticker
# 0  0.100543   9012.0      562.87 2024-08-23    SPY
# 1  0.262774  14538.0      562.87 2024-08-23    SPY
#
# [2 rows x 21 columns]
# Exposure is : -104859.34
# Qty to sell is -3
# Processing timestamp  2024-08-23 10:45:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-08-26   565.0    4           1 2024-08-23 14:45:00  0.940  0.940
# 1 2024-08-26   564.0    4           1 2024-08-23 14:45:00  1.310  1.310
# 2 2024-08-23   563.0    1           1 2024-08-23 14:45:00  0.985  0.985
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  0.940  0.940   280.0  ...    226.0      0.93      0.95  0.101174  0.102334
# 1  1.310  1.310   313.0  ...    134.0      1.30      1.32  0.104225  0.105269
# 2  0.985  0.985  1216.0  ...    407.0      0.98      0.99  0.270792  0.272707
#
#          iv       oi  stockPrice        day ticker
# 0  0.101754   9012.0      561.83 2024-08-23    SPY
# 1  0.104747   4764.0      561.83 2024-08-23    SPY
# 2  0.271750  15194.0      561.83 2024-08-23    SPY
#
# [3 rows x 21 columns]
# Exposure is : 295615.07971562503
# Qty to sell is 9
#   ✅ 2024-08-23: SCALED IN by selling 9 contracts of strike 565.0
# Processing timestamp  2024-08-23 11:00:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-08-26   563.0    4           1 2024-08-23 15:00:00  1.225  1.225
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.225  1.225   101.0  ...     20.0      1.22      1.23  0.102823  0.103403
#
#          iv      oi  stockPrice        day ticker
# 0  0.103113  5828.0      560.63 2024-08-23    SPY
#
# [1 rows x 21 columns]
# Exposure is : 494926.4059521485
# Qty to sell is 15
#   ✅ 2024-08-23: SCALED IN by selling 15 contracts of strike 563.0
# Processing timestamp  2024-08-23 11:15:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-08-26   564.0    4           1 2024-08-23 15:15:00  1.025  1.025
# 1 2024-08-26   563.0    4           1 2024-08-23 15:15:00  1.410  1.410
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.025  1.025    61.0  ...    160.0      1.02      1.03  0.096393  0.096962
# 1  1.410  1.410   240.0  ...    130.0      1.40      1.42  0.098134  0.099165
#
#          iv      oi  stockPrice        day ticker
# 0  0.096678  4764.0      561.26 2024-08-23    SPY
# 1  0.098649  5828.0      561.26 2024-08-23    SPY
#
# [2 rows x 21 columns]
# Exposure is : 598768.4506535156
# Qty to sell is 18
#   ✅ 2024-08-23: SCALED IN by selling 18 contracts of strike 564.0
#    Expiring position with strike 565.0 on 2024-08-26
#    Found 3 prices in closing window. Avg exit price: $0.01
# Pnl of hedge was 828.0000000000001
#    Expiring position with strike 563.0 on 2024-08-26
#    Found 3 prices in closing window. Avg exit price: $0.01
# Pnl of hedge was 1814.9999999999998
#    Expiring position with strike 564.0 on 2024-08-26
#    Found 3 prices in closing window. Avg exit price: $0.01
# Pnl of hedge was 1818.0
#   ⚠️ 2024-08-27: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-08-28: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-08-28: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-08-29 10:15:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-08-30   564.0    2           1 2024-08-29 14:15:00  1.085  1.085
# 1 2024-08-30   563.0    2           1 2024-08-29 14:15:00  1.470  1.470
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.085  1.085   220.0  ...     70.0      1.08      1.09  0.160403  0.161255
# 1  1.470  1.470   341.0  ...    266.0      1.46      1.48  0.162881  0.164462
#
#          iv       oi  stockPrice        day ticker
# 0  0.160829  10005.0      561.08 2024-08-29    SPY
# 1  0.163672  11764.0      561.08 2024-08-29    SPY
#
# [2 rows x 21 columns]
# Exposure is : 599600.4467607116
# Qty to sell is 18
#   ✅ 2024-08-29: SCALED IN by selling 18 contracts of strike 564.0
#    Expiring position with strike 564.0 on 2024-08-30
#    Found 3 prices in closing window. Avg exit price: $0.36
# Pnl of hedge was 1290.0000000000002
#   ⚠️ 2024-08-30: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-08-30 10:00:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-09-03   564.0    5           1 2024-08-30 14:00:00  1.065  1.065
# 1 2024-09-03   563.0    5           1 2024-08-30 14:00:00  1.465  1.465
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.065  1.065    38.0  ...    172.0      1.06      1.07  0.080851  0.081303
# 1  1.465  1.465    75.0  ...     98.0      1.46      1.47  0.082337  0.082761
#
#          iv      oi  stockPrice        day ticker
# 0  0.081077  5681.0      561.73 2024-08-30    SPY
# 1  0.082549  5599.0      561.73 2024-08-30    SPY
#
# [2 rows x 21 columns]
# Exposure is : 611520.9844578552
# Qty to sell is 18
#   ✅ 2024-08-30: SCALED IN by selling 18 contracts of strike 564.0
#    Expiring position with strike 564.0 on 2024-09-03
#    Found 3 prices in closing window. Avg exit price: $0.01
# Pnl of hedge was 1890.0000000000002
#   ⚠️ 2024-09-03: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-09-03: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-09-03: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-09-03: Received SCALE_OUT signal, but no open positions.
# Processing timestamp  2024-09-04 11:15:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-09-05   557.0    2           1 2024-09-04 15:15:00  0.965  0.965
# 1 2024-09-05   556.0    2           1 2024-09-04 15:15:00  1.290  1.290
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  0.965  0.965    90.0  ...      1.0      0.96      0.97  0.188884  0.189794
# 1  1.290  1.290    60.0  ...    413.0      1.28      1.30  0.191766  0.193501
#
#          iv      oi  stockPrice        day ticker
# 0  0.189339  4348.0      553.14 2024-09-04    SPY
# 1  0.192633  3318.0      553.14 2024-09-04    SPY
#
# [2 rows x 21 columns]
# Exposure is : 99075.2220678711
# Qty to sell is 3
#   ✅ 2024-09-04: SCALED IN by selling 3 contracts of strike 557.0
# Processing timestamp  2024-09-04 11:45:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-09-05   556.0    2           1 2024-09-04 15:45:00  0.955  0.955
# 1 2024-09-05   555.0    2           1 2024-09-04 15:45:00  1.275  1.275
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  0.955  0.955    26.0  ...    246.0      0.95      0.96  0.194316  0.195300
# 1  1.275  1.275    57.0  ...    202.0      1.27      1.28  0.197353  0.198272
#
#          iv      oi  stockPrice        day ticker
# 0  0.194808  3318.0      551.95 2024-09-04    SPY
# 1  0.197813  3751.0      551.95 2024-09-04    SPY
#
# [2 rows x 21 columns]
# Exposure is : 397353.7532470703
# Qty to sell is 12
#   ✅ 2024-09-04: SCALED IN by selling 12 contracts of strike 556.0
#    Expiring position with strike 557.0 on 2024-09-05
#    Found 3 prices in closing window. Avg exit price: $0.01
# Pnl of hedge was 284.99999999999994
#    Expiring position with strike 556.0 on 2024-09-05
#    Found 3 prices in closing window. Avg exit price: $0.01
# Pnl of hedge was 1128.0
# Processing timestamp  2024-09-05 10:15:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-09-06   558.0    2           1 2024-09-05 14:15:00  1.055  1.055
# 1 2024-09-06   557.5    2           1 2024-09-05 14:15:00  1.200  1.200
# 2 2024-09-06   557.0    2           1 2024-09-05 14:15:00  1.355  1.355
# 3 2024-09-05   553.0    1           1 2024-09-05 14:15:00  1.045  1.045
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.055  1.055    43.0  ...     30.0      1.05      1.06  0.244809  0.245744
# 1  1.200  1.200    22.0  ...    575.0      1.19      1.21  0.246754  0.248519
# 2  1.355  1.355   179.0  ...    130.0      1.35      1.36  0.249714  0.250556
# 3  1.045  1.045  1684.0  ...    234.0      1.04      1.05  0.273783  0.275533
#
#          iv      oi  stockPrice        day ticker
# 0  0.245277  5071.0      551.83 2024-09-05    SPY
# 1  0.247637  1575.0      551.83 2024-09-05    SPY
# 2  0.250135  5795.0      551.83 2024-09-05    SPY
# 3  0.274658  7668.0      551.83 2024-09-05    SPY
#
# [4 rows x 21 columns]
# Exposure is : 406824.3277142334
# Qty to sell is 12
#   ✅ 2024-09-05: SCALED IN by selling 12 contracts of strike 558.0
# Processing timestamp  2024-09-05 10:30:00
# Found data of options as       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-09-06   558.0    2           1 2024-09-05 14:30:00  1.175  1.175
# 1 2024-09-06   557.5    2           1 2024-09-05 14:30:00  1.340  1.340
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.175  1.175   382.0  ...    188.0      1.17      1.18  0.230871  0.231751
# 1  1.340  1.340   233.0  ...    257.0      1.33      1.35  0.233133  0.234900
#
#          iv      oi  stockPrice        day ticker
# 0  0.231311  5071.0      552.89 2024-09-05    SPY
# 1  0.234016  1575.0      552.89 2024-09-05    SPY
#
# [2 rows x 21 columns]
# Exposure is : 606977.0691117248
# Qty to sell is 18
#   ✅ 2024-09-05: SCALED IN by selling 18 contracts of strike 558.0
#    Expiring position with strike 558.0 on 2024-09-06
#    Found 3 prices in closing window. Avg exit price: $0.01
# Pnl of hedge was 1248.0
#    Expiring position with strike 558.0 on 2024-09-06
#    Found 3 prices in closing window. Avg exit price: $0.01
# Pnl of hedge was 2088.0
#   ⚠️ 2024-09-06: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-09-06: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-09-06: Received SCALE_OUT signal, but no open positions.
#   ⚠️ 2024-09-06: Received SCALE_OUT signal, but no open positions.
#
# ✅ Backtest finished.

# %%
tl = pd.DataFrame(trade_log)

# %%
options_data
# Out:
#       expiry  strike  dte  optionType                  ts    low   high  \
# 0 2024-09-06   558.0    2           1 2024-09-05 14:30:00  1.175  1.175
# 1 2024-09-06   557.5    2           1 2024-09-05 14:30:00  1.340  1.340
#
#     open  close  volume  ...  askSize  bidPrice  askPrice     bidIv     askIv  \
# 0  1.175  1.175   382.0  ...    188.0      1.17      1.18  0.230871  0.231751
# 1  1.340  1.340   233.0  ...    257.0      1.33      1.35  0.233133  0.234900
#
#          iv      oi  stockPrice        day ticker
# 0  0.231311  5071.0      552.89 2024-09-05    SPY
# 1  0.234016  1575.0      552.89 2024-09-05    SPY
#
# [2 rows x 21 columns]

# %%
tl['pnl'].dropna().cumsum()
# Out:
# 0       420.000000
# 1     -1344.000000
# 2       616.000000
# 3     -3753.000000
# 4     -7206.333333
#           ...
# 56   -24057.000000
# 57   -23676.000000
# 58   -22164.000000
# 59   -20916.000000
# 60   -18828.000000
# Name: pnl, Length: 61, dtype: float64

# %%
import pandas as pd

def find_straddle_for_day(con, ticker, timestamp, expiry_str, percentage_away):
    """
    Finds the closest matching call and put options for a straddle for an entire day.

    Args:
        con: The DuckDB connection object.
        ticker (str): The stock ticker (e.g., 'SPY').
        timestamp (pd.Timestamp): The reference timestamp to determine the stock price.
        expiry_str (str): The expiry date for the options, in 'YYYY-MM-DD' format.
        percentage_away (float): The percentage to calculate strike distance (e.g., 0.01 for 1%).

    Returns:
        pd.DataFrame: A DataFrame with the full day's data for the two selected options.
    """
    date_str = timestamp.strftime('%Y-%m-%d')
    utc_timestamp_str = timestamp.tz_localize('America/New_York').tz_convert('UTC').strftime('%Y-%m-%d %H:%M:%S')

    print(f"Finding straddle for {ticker} on {date_str} with {percentage_away:.2%} offset...")

    try:
        query = f"""
            WITH TargetInfo AS (
                SELECT 
                    stockPrice AS reference_price,
                    stockPrice * (1 + {percentage_away}) AS target_call_strike,
                    stockPrice * (1 - {percentage_away}) AS target_put_strike
                FROM read_parquet('s3://duckdata/ORATS/Options/ticker={ticker}/day={date_str}/*.parquet')
                WHERE ts = '{utc_timestamp_str}'
                LIMIT 1
            )
            SELECT 
                ts, strike, expiry, dte, optionType, volume, oi,
                bidPrice, askPrice, bidIv, askIv, iv, stockPrice, ticker
            FROM read_parquet('s3://duckdata/ORATS/Options/ticker={ticker}/day={date_str}/*.parquet')
            WHERE
                expiry = '{expiry_str}'
            QUALIFY
                ROW_NUMBER() OVER (
                    PARTITION BY optionType 
                    ORDER BY 
                        ABS(strike - CASE 
                                        WHEN optionType = 1 THEN (SELECT target_call_strike FROM TargetInfo)
                                        ELSE (SELECT target_put_strike FROM TargetInfo)
                                     END)
                ) = 1
            ORDER BY ts, optionType;
        """
        
        straddle_df = con.execute(query).df()
        
        if straddle_df.empty:
            print("INFO: Could not find matching straddle options.")
        
        return straddle_df

    except Exception as e:
        print(f"An error occurred: {e}")
        return pd.DataFrame()

# --- Example Usage ---

# Assume 'con' is your active DuckDB connection

# %%
# 1. Define the parameters
target_ticker = 'SPY'
reference_timestamp = pd.to_datetime('2024-09-06 09:30:00') # The time to check the stock price
target_expiry = '2024-09-06'
percentage_offset = 0.005 # 0.5% away from the stock price

straddle_data_df = find_straddle_for_day(
    con=con,
    ticker=target_ticker,
    timestamp=reference_timestamp,
    expiry_str=target_expiry,
    percentage_away=percentage_offset
)

if not straddle_data_df.empty:
    print("\n--- Found Straddle Data ---")
    # You will get all the day's data for two strikes: one call and one put
    print(straddle_data_df)
    print("\nSelected Strikes:")
    print(straddle_data_df['strike'].unique())
# Out:
# Finding straddle for SPY on 2024-09-06 with 0.50% offset...
#
# --- Found Straddle Data ---
#                    ts  strike     expiry  dte  optionType  volume      oi  \
# 0 2024-09-06 18:21:00   547.0 2024-09-06    1          -1    87.0  8542.0
# 1 2024-09-06 19:51:00   552.5 2024-09-06    1           1     1.0  5042.0
#
#    bidPrice  askPrice  bidIv     askIv        iv  stockPrice ticker
# 0      6.83      6.92    0.0  0.525913  0.525913      540.12    SPY
# 1      0.00      0.01    0.0  0.749761  0.749761      540.39    SPY
#
# Selected Strikes:
# [547.  552.5]

# %%
import pandas as pd

def find_straddle_at_timestamp(con, ticker, timestamp, expiry_str, underlying_price, percentage_away):
    """
    Finds the closest matching call and put for a straddle at a single timestamp.

    Args:
        con: The DuckDB connection object.
        ticker (str): The stock ticker (e.g., 'SPY').
        timestamp (pd.Timestamp): The specific timestamp to query (e.g., in EST).
        expiry_str (str): The expiry date for the options, in 'YYYY-MM-DD' format.
        underlying_price (float): The reference stock price to calculate strikes from.
        percentage_away (float): The percentage to calculate strike distance.

    Returns:
        pd.DataFrame: A DataFrame with the data for the two selected options,
                      or an empty DataFrame if not found.
    """
    # date_str = timestamp.strftime('%Y-%m-%d')
    # utc_timestamp_str = timestamp.tz_localize('America/New_York').tz_convert('UTC').strftime('%Y-%m-%d %H:%M:%S')
    
    # 1. Check if the input timestamp is naive (has no timezone info)
    if timestamp.tzinfo is None or timestamp.tzinfo.utcoffset(timestamp) is None:
        # If it's naive, localize it to New York time
        timestamp = timestamp.tz_localize('America/New_York')
    
    # 2. Now that we're sure it's timezone-aware, we can safely convert to UTC for the query
    date_str = timestamp.strftime('%Y-%m-%d')
    utc_timestamp_str = timestamp.tz_convert('UTC').strftime('%Y-%m-%d %H:%M:%S')
    

    print(f"Finding straddle for {ticker} at {timestamp} with {percentage_away:.2%} offset...")

    try:
        # Calculate target strikes directly in Python
        target_call_strike = underlying_price * (1 + percentage_away)
        target_put_strike = underlying_price * (1 - percentage_away)

        # The query is now faster with the added 'ts' filter
        query = f"""
            SELECT 
                ts, strike, expiry, dte, optionType, volume, oi,
                bidPrice, askPrice, bidIv, askIv, iv, stockPrice, ticker
            FROM read_parquet('s3://duckdata/ORATS/Options/ticker={ticker}/day={date_str}/*.parquet')
            WHERE
                ts = '{utc_timestamp_str}' AND -- <-- KEY CHANGE: Filter for the exact timestamp
                expiry = '{expiry_str}'
            QUALIFY
                ROW_NUMBER() OVER (
                    PARTITION BY optionType 
                    ORDER BY 
                        ABS(strike - CASE 
                                        WHEN optionType = 1 THEN {target_call_strike}
                                        ELSE {target_put_strike}
                                     END)
                ) = 1;
        """
        
        straddle_df = con.execute(query).df()
        
        if straddle_df.empty:
            print("INFO: Could not find matching straddle options at this timestamp.")
        
        straddle_df['ts'] = pd.to_datetime(straddle_df['ts'].dt.tz_localize('UTC').dt.tz_convert('America/New_York').dt.tz_localize(None))

        return straddle_df

    except Exception as e:
        print(f"An error occurred: {e}")
        return pd.DataFrame()



# --- Example Usage ---

# Assume 'con' is your active DuckDB connection
# 1. Define the parameters
target_ticker = 'SPY'
target_timestamp = pd.to_datetime('2024-09-09 09:30:00') # Specific time
target_expiry = '2024-09-09'
reference_price = 540.15 
percentage_offset = 0.005 

# 2. Call the function
straddle_data_df = find_straddle_at_timestamp(
    con=con,
    ticker=target_ticker,
    timestamp=target_timestamp,
    expiry_str=target_expiry,
    underlying_price=reference_price,
    percentage_away=percentage_offset
)

if not straddle_data_df.empty:
    print("\n--- Found Straddle Data at Timestamp ---")
    print(straddle_data_df)
# Out:
# Finding straddle for SPY at 2024-09-09 09:30:00-04:00 with 0.50% offset...
#
# --- Found Straddle Data at Timestamp ---
#                    ts  strike     expiry  dte  optionType   volume      oi  \
# 0 2024-09-09 09:30:00   537.0 2024-09-09    1          -1 -32163.0  6159.0
# 1 2024-09-09 09:30:00   543.0 2024-09-09    1           1 -36912.0  5349.0
#
#    bidPrice  askPrice     bidIv     askIv        iv  stockPrice ticker
# 0      1.39      1.41  0.000000  0.254944  0.254944      544.68    SPY
# 1      1.26      1.28  0.015941  0.019643  0.017792      544.68    SPY

# %%
import pandas as pd
import numpy as np
import pandas_market_calendars as mcal
import duckdb

# ==============================================================================
# 0. SETUP: Create Sample Data and a Mock Database
# ==============================================================================


# ==============================================================================
# BACKTESTING LOGIC
# ==============================================================================

# --- Essential Change: Use a list to track multiple position layers ---
open_positions = []
trade_log = []
option_multiplier = 100
hedge_ratio = 0.50

nyse = mcal.get_calendar('NYSE')
print("\n🚀 Starting backtest with dynamic quantity...")

# Loop through each row of your exposure data
for timestamp, row in rdf.iterrows():
    marker = row['change_posn']
    current_exposure = row['net_exposure']
    change_in_exposure = row['change_in_exposure']

    # --- 1. HANDLE EXPIRATIONS FIRST ---
    positions_to_keep = []
    if open_positions:
        for position in open_positions:
            expiry_date = pd.to_datetime(position['expiry']).date()
            if timestamp.date() >= expiry_date:
                print(f"   Expiring position with strike {position['strike']} on {timestamp.date()}")
                exit_price = 0.05 # Simulate fetching a closing price
                pnl = (position['entry_price'] - exit_price) * position['quantity'] * option_multiplier
                position.update({'exit_ts': timestamp, 'exit_price': exit_price, 'pnl': pnl, 'exit_reason': 'Expired'})
                trade_log.append(position)
            else:
                positions_to_keep.append(position)
        open_positions = positions_to_keep

    # --- 2. HANDLE SIGNALS (SCALE OUT or SCALE IN) ---
    if marker == -1:
        if not open_positions:
            print(f"  ⚠️ {timestamp.date()}: Received SCALE_OUT signal, but no open positions.")
            continue
        
        decline_in_exposure = abs(change_in_exposure)
        asset_price_at_event = row['net_exposure'] / (row['net_exposure'] / 475) # Estimate price
        
        # Use parameters of the oldest position (FIFO) to calculate contracts to close
        oldest_pos = open_positions[0]
        delta_per_contract = oldest_pos['initial_delta'] * option_multiplier

        shares_to_unwind = decline_in_exposure * hedge_ratio / asset_price_at_event
        contracts_to_close = int(round(shares_to_unwind / delta_per_contract))

        if contracts_to_close > 0:
            print(f"  🔽 {timestamp.date()}: SCALING OUT by closing {contracts_to_close} contracts...")
            remaining_to_close = contracts_to_close
            temp_open_positions = []
            for position in open_positions:
                if remaining_to_close <= 0:
                    temp_open_positions.append(position)
                    continue
                
                closable_qty = min(position['quantity'], remaining_to_close)
                # In a real backtest, you would log the partial close as a trade
                position['quantity'] -= closable_qty
                remaining_to_close -= closable_qty
                
                if position['quantity'] > 0:
                    temp_open_positions.append(position)
            
            open_positions = temp_open_positions

    elif marker == 1:
        # This logic now handles both initial entry and scaling in
        increase_in_exposure = change_in_exposure
        if increase_in_exposure <= 0:
            continue

        try:
            # --- Your original data fetching logic ---
            schedule = nyse.schedule(start_date=timestamp.date(), end_date=timestamp.date() + pd.Timedelta(days=5))
            # Ensure schedule is not empty and has a second day
            if len(schedule) > 1:
                next_trading_day = schedule.index[1].date()
            else: # Handle holidays or weekends
                next_trading_day = nyse.schedule(start_date=timestamp.date() + pd.Timedelta(days=1), end_date=timestamp.date() + pd.Timedelta(days=7)).index[0].date()
            
            
            
            utc_timestamp_for_query = timestamp.tz_localize('America/New_York').tz_convert('UTC')
            utc_timestamp_str = utc_timestamp_for_query.strftime('%Y-%m-%d %H:%M:%S')
            #print(f"Searching UTC timestamp as {utc_timestamp_str}")
            
            options_data = con.execute(f"""
                SELECT *
                FROM read_parquet('s3://duckdata/ORATS/Options/ticker=SPY/day={timestamp.strftime('%Y-%m-%d')}/*.parquet')
                WHERE 
                    ts = '{utc_timestamp_str}'  AND
                    optionType = 1 AND
                    expiry BETWEEN '{timestamp.strftime('%Y-%m-%d')}' AND '{expiry_date_str}' AND
                    strike>stockPrice*1.001 AND
                    bidPrice>1
                ORDER BY abs(strike - stockPrice) DESC
                LIMIT 5;
            """).df()       

           

            if not options_data.empty:
                target_option = options_data.iloc[0]
                
                asset_price_at_entry = target_option['stockPrice']
                delta_of_option = 0.45
                delta_per_contract = delta_of_option * option_multiplier

                # Correctly hedge the INCREASE in exposure
                notional_to_hedge = increase_in_exposure * hedge_ratio
                shares_to_hedge = notional_to_hedge / asset_price_at_entry
                
                qty_to_sell = 0
                if delta_per_contract > 0:
                    qty_to_sell = int(round(shares_to_hedge / delta_per_contract))

                if qty_to_sell > 0:
                    new_position = {
                        'entry_ts': timestamp, 'strike': target_option['strike'], 'expiry': expiry_date_str,
                        'entry_price': target_option['bidPrice'], 'quantity': qty_to_sell, 'initial_delta': delta_of_option
                    }
                    open_positions.append(new_position)
                    print(f"  ✅ {timestamp.date()}: SCALED IN by selling {qty_to_sell} contracts of strike {new_position['strike']}")
            else:
                print(f"  ⚠️ {timestamp.date()}: No options data found for this entry signal.")
        except Exception as e:
            print(f"  ❌ Error processing {timestamp}: {e}")

# --- 3. Close any remaining positions at the end of the backtest ---
for pos in open_positions:
    pos['exit_reason'] = 'End of Backtest'
    trade_log.append(pos)

print("\n✅ Backtest finished.")

# ==============================================================================
# 4. REVIEW RESULTS
# ==============================================================================
print("\n--- FINAL TRADE LOG ---")
if trade_log:
    log_df = pd.DataFrame(trade_log)
    print(log_df[['entry_ts', 'strike', 'quantity', 'entry_price', 'exit_ts', 'exit_price', 'pnl', 'exit_reason']].round(2))
else:
    print("No trades were executed.")
